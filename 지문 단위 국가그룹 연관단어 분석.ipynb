# %%
import os
import glob
from tqdm.notebook import tqdm
import networkx as nx
import time
import pandas as pd

# %%
os.chdir(r'C:\Users\Kislee\PycharmProjects\Korean_textbook')
DATA_PATH = os.getcwd() + r'\target_data'
print(DATA_PATH)
# Out:
# C:\Users\Kislee\PycharmProjects\Korean_textbook\target_data

# %%
files = glob.glob(os.path.join(DATA_PATH, '*.xlsx'))

# %%
all_dfs = []
for source in files:
    temp_df = pd.read_excel(source, engine='openpyxl')
    all_dfs.append(temp_df)
df = pd.concat(all_dfs)

# %%
df.head()
# Out:
#    학교명 등급                                                 지문  외국인인명   국가명  민족명
# 0  경희대  5  장민: 어제 요리 프로그램에서 제철 음식을 가지고 누가 더 맛 있게 만드는지 대결을...  장민/한나   NaN  NaN
# 1  경희대  5  흐엉: 장민, 이 제육볶음 좀 먹어 봐. 어제 마을 장터에 갔는데 직접 만든 고추장...     장민   NaN  NaN
# 2  경희대  5  은영: 승진 시험 준비는 잘 되어 가?\n상진: 그냥 그래. 요즘 일도 공부도 손에...     상진   NaN  NaN
# 3  경희대  5  의학 전문가: 여러분은 어떻게 휴식을 하십니까? 집에서 텔레비전을 보면서 쉬신다고요...    윤태훈   NaN  NaN
# 4  경희대  5  예술 교육은 우리의 삶에 어떤 영향을 줄까요? 그에 대한 하나의 대답으로 콜롬비아의...    NaN  콜롬비아  NaN

# %%
cell_df = df['지문']

# %%
#UTagger
from Utagger.bin.utagger_py import UTagger

# %%
os.chdir(r'C:\Users\Kislee\PycharmProjects\Korean_textbook\Utagger\한국어교재지문')
print(os.getcwd())
# Out:
# C:\Users\Kislee\PycharmProjects\Korean_textbook\Utagger\한국어교재지문

# %%
dllpath = r'../bin/UTaggerR64.dll'
cfgpath = r'../Hlxcfg.txt'

rt = UTagger.Load_global(dllpath, cfgpath)
ut = UTagger(0) # 0은 객체 고유번호. 0~99 지정 가능. 같은 번호로 여러번 생성하면 안됨. 한 스레드당 하나씩 지정 필요.
rt = ut.new_ucma() #객체 생성. 객체가 있어야 유태거 이용 가능.
# Out:
# python call utagger function
# C:\Users\Kislee\PycharmProjects\Korean_textbook\Utagger\Hlxcfg.txt

# %%
cell_utagging = [ut.tag_line(cell,3) for cell in tqdm(cell_df)]
# Out:
#   0%|          | 0/475 [00:00<?, ?it/s]

# %%
ut.release_ucma() #객체 해제
UTagger.Release_global() #사전 해제

# %%
#단어 어깨번호 정제하고자 할 때 사용
def cutSemanticNum(word, all=False): # all : True이면 의미숫자를 다 잘라버림, False이면 두글자만 남김
    splitted = word.split('__')
    
    if len(splitted) == 1: # __ 구분자가 없는단어는 원 단어 그대로 반환
        return word
    
    if all==True:
        return splitted[0]
    
    out_word = splitted[0]+'__'+splitted[1][-2:]
    return out_word

# %%
# utagger 가 생성한 한 어절에서 + 단위로 형태소를 자른 후 / 단위로 어휘와 태그를 분석
def utagging_to_simple_tagging(utg):
    #outlier가 발견되어 제거함
    utg = utg.replace('NNG\n','NNG')
    
    temp_wordset = utg.split('+') # utagger 가 생성한 결과에서 + 단위로 잘라줌
   
    wordset = []
    for word_tag in temp_wordset:
        seplist = word_tag.split('/') #/ 로 잘라지지 않는 경우에 대한 예외처리
        if len(seplist) <= 1 :
            continue
        else :
            wordset.append(seplist)
    if len(wordset) <= 0:
        return None
   
    try:
        first_word = wordset[0][0]
        first_tag = wordset[0][1]
    except:
        print("예외처리 : ", wordset)
    
    #동사(VV), 형용사(VA)로 시작하면 바로 첫 단어만 내보냄
    if first_tag.startswith('VV') or first_tag.startswith('VA'):
        return (first_word, first_tag)
    
    if len(wordset) == 1: #한 단어인 경우 
         #명사류, 부사, 한글자 이상의 외국어는 사용
        if first_tag.startswith('NNP') or first_tag.startswith('NNG') or first_tag.startswith('MAG') or (first_tag.startswith('SL') and len(first_word)>1) :
            #if word_tag[1].startswith('SL'):
            #            print(word_tag[0])
            return (first_word, first_tag)

    else: #여러 단어인 경우 
        if first_tag.startswith('NNP') or first_tag.startswith('NNG') or first_tag.startswith('SL') or first_tag.startswith('XPN'): #첫 단어가 다음과 같으면
            output = []
            
            if first_tag.startswith('XPN'): #XPN+NNG 는 합쳐서 NNG로
                second_word = wordset[1][0]
                second_tag = wordset[1][1]
                if second_tag.startswith('NNG'):
                        output.append((cutSemanticNum(first_word,True)+second_word, second_tag))
                        #print(output[0])
                return output
            
            for word_tag in wordset: #XPN+NNG 로 반환해야함--> NNG로
                if word_tag[1].startswith('NNP') or word_tag[1].startswith('NNG') or (word_tag[1].startswith('SL') and len(word_tag[0])>1): #명사류를 찾음
                    #if word_tag[1].startswith('SL'): #지울 것
                    #    print(word_tag[0])
                    output.append((word_tag[0], word_tag[1]))
            return output

    return None

#문장 전체를 받아서 (단어,태그) 튜플 리스트로 반환
def remain_available_words(doc): 
    result = []
    for utg in doc.split(' '):
        simple_tagged = utagging_to_simple_tagging(utg)
        if simple_tagged == None:
            continue
                
        if str(type(simple_tagged)) =="<class 'tuple'>":
            result.append(simple_tagged)
        else :
            for word_tag in simple_tagged:
                result.append(word_tag)
    return result

# %%
cell_tagging = [remain_available_words(cell) for cell in cell_utagging]

# %%
#불용어 수집
os.chdir(r'C:\Users\Kislee\PycharmProjects\Korean_textbook')
DATA_PATH = os.getcwd()
filename = DATA_PATH+r'\불용어목록.xlsx'
stopword_df = pd.read_excel(filename, engine='openpyxl')

# %%
#불용어 제거 필터
stopword = list(stopword_df['불용어'])
def stopword_filter(cell):
    output = []
    for word, tag in cell:
        if word not in stopword:
            output.append((word,tag))
    return output

# %%
cell_tagging = [stopword_filter(cell) for cell in cell_tagging]

# %%
#태그:빈도 사전구성
tag_freq_dic = {}
for cell in cell_tagging:
    for word, tag in cell:
        tag_freq_dic[tag] = tag_freq_dic.get(tag, 0) + 1
print("고유 태그 수 : %d" % len(tag_freq_dic))
# Out:
# 고유 태그 수 : 6

# %%
#단어:태그 사전구성
word_tag_dic = {}
for cell in cell_tagging:
    for word, tag in cell:
        word_tag_dic[word] = tag

# %%
#셀내의 튜플 리스트에서 워드만 추출
def word_selector(cell):
    output = []
    for word, tag in cell:
        if word not in stopword:
            output.append(word)
    return output

# %%
cell_wordlist = [word_selector(cell) for cell in cell_tagging]

# %%
#파일 저장을 위한 일회성 코드
#out_df = pd.DataFrame(cell_utagging)
#out_df.to_excel('utag_result1012.xlsx')

# %%
#EDA
print("지문 수 : ", len(cell_wordlist))
# Out:
# 지문 수 :  475

# %%
cnt = 0
for cell in cell_wordlist:
    cnt += len(cell)
print('단어 출현 수 :', cnt)
# Out:
# 단어 출현 수 : 91307

# %%
#단어:빈도 사전
word_freq_dic = {}
for cell in cell_wordlist:
    for word in cell:
        word_freq_dic[word] = word_freq_dic.get(word, 0) + 1
print("고유 단어 수 : %d" % len(word_freq_dic))
# Out:
# 고유 단어 수 : 11272

# %%
word_freq = []
for key, value in word_freq_dic.items():
    word_freq.append((value, key))
word_freq.sort(reverse=True)
print("상위단어 정렬", word_freq[:1000])
# Out:
# 상위단어 정렬 [(2890, '있__01'), (1038, '보__01'), (897, '사람'), (624, '같'), (539, '없__01'), (463, '많'), (437, '남자__02'), (433, '생각하'), (430, '좋__01'), (428, '여자__02'), (415, '한국__05'), (338, '일__01'), (338, '더__01'), (329, '말__01'), (322, '만들'), (297, '문제__06'), (293, '크__01'), (285, '잘__02'), (284, '가__01'), (278, '알'), (271, '듣__01'), (268, '사회__07'), (266, '시간__04'), (262, '받__01'), (254, '학생'), (252, '사회자'), (249, '오늘'), (241, '생각__01'), (236, '살__01'), (235, '들__01'), (231, '많이'), (231, '가지'), (223, '지금__03'), (214, '자신__01'), (212, '먹__02'), (209, '주__01'), (200, '또'), (199, '오__01'), (193, '경우__03'), (189, '문화__01'), (188, '중요하__02'), (188, '쓰__03'), (187, '아이__01'), (184, '따르__01'), (179, '좀__02'), (179, '안__02'), (173, '말하'), (173, '느끼__02'), (171, '필요하'), (171, '경제__04'), (170, '영화__01'), (167, '안녕하'), (164, '가장__01'), (163, '나오'), (162, '맞__01'), (162, '교수__06'), (158, '세계__02'), (157, '이야기'), (156, '음악__01'), (153, '사용하__03'), (151, '사실__04'), (150, '말씀'), (150, '다양하__01'), (147, '정도__11'), (147, '요즘'), (147, '나라__01'), (145, '음식'), (144, '돈__01'), (142, '친구__02'), (142, '최근'), (142, '교육'), (141, '바로__02'), (140, '찾'), (138, '모르'), (137, '진행자'), (137, '생활'), (137, '기자__05'), (134, '먼저'), (133, '한옥'), (131, '속__01'), (129, '정말__01'), (129, '모두__01'), (128, '이유__04'), (128, '이번__01'), (128, '가족__01'), (127, '집__01'), (127, '내용__02'), (126, '방법'), (126, '나누'), (125, '함께'), (125, '이제__01'), (125, '모습__01'), (124, '어렵'), (124, '시대__02'), (122, '선생님'), (122, '기업__01'), (121, '의견__01'), (120, '다__03'), (116, '앞'), (116, '내__02'), (114, '변화'), (113, '의미__02'), (113, '쉽'), (113, '다르__01'), (112, '소비자'), (112, '상황__02'), (111, '다시__01'), (111, '광고__02'), (110, '힘들'), (108, '마음__01'), (108, '다음__01'), (107, '현재__02'), (107, '전__08'), (107, '새롭'), (106, '활동__02'), (105, '처음'), (105, '만나'), (105, '관심__01'), (103, '전문가'), (101, '또한'), (100, '지역__03'), (100, '능력__02'), (99, '대학__01'), (98, '방식__01'), (98, '나타나'), (97, '전통__06'), (97, '삶'), (97, '도움'), (96, '시작하__01'), (96, '배우__01'), (95, '감사하__05'), (94, '높'), (91, '과정__03'), (90, '특히'), (90, '보이__02'), (89, '정보__06'), (89, '인간__01'), (89, '너무__01'), (88, '이상__05'), (88, '공간__05'), (88, '결과__02'), (87, '회사__04'), (87, '상품__03'), (86, '학교'), (86, '읽'), (86, '역사__04'), (86, '남__01'), (86, '날__01'), (85, '인터넷'), (85, '왜__02'), (85, '얻__01'), (84, '표현'), (82, '부르__01'), (81, '하나'), (81, '기술__01'), (80, '과학'), (79, '환경__02'), (79, '제품__02'), (79, '몸__01'), (78, '차이'), (78, '아주__01'), (76, '해결하'), (76, '물론__01'), (75, '질문'), (75, '부분__01'), (75, '발전__01'), (74, '힘__01'), (74, '커피'), (74, '살펴보'), (73, '드라마'), (73, '관계__05'), (72, '직접'), (71, '여성__01'), (71, '빠르'), (69, '이용하__01'), (69, '길__01'), (68, '필요'), (68, '인기__01'), (68, '에너지'), (68, '언어__01'), (68, '미래__02'), (68, '마을__01'), (68, '갖__01'), (67, '영향__04'), (67, '말씀하'), (67, '경기__11'), (67, '같이'), (66, '효과__01'), (66, '예술'), (66, '사진__07'), (66, '가치__06'), (65, '손__01'), (64, '책__01'), (64, '이해하__02'), (64, '우리나라'), (64, '서로__01'), (64, '드리__01'), (64, '뉴스'), (64, '눈__01'), (64, '노래__01'), (63, '자리__01'), (63, '역할'), (63, '동안__01'), (63, '도시__03'), (62, '옷__01'), (62, '실험'), (62, '세대__02'), (62, '노인__01'), (62, '국가__01'), (62, '계속__04'), (62, '개인__02'), (61, '입__01'), (61, '우선__02'), (61, '수업__04'), (61, '분야'), (61, '모시'), (61, '들어가__01'), (61, '다니'), (61, '과거__03'), (60, '주제__04'), (60, '외국인'), (60, '남__04'), (59, '한국어'), (59, '작품__01'), (59, '안__01'), (59, '세상__01'), (59, '보내'), (59, '기능__03'), (59, '국민'), (58, '지구__04'), (58, '일하'), (58, '영어__02'), (58, '물건'), (58, '마지막'), (57, '한국인'), (57, '서울__01'), (57, '나__01'), (57, '꼭__03'), (56, '좋아하'), (56, '살아가'), (56, '사랑__01'), (56, '발표__01'), (56, '물__01'), (56, '대부분'), (56, '노력__01'), (56, '나이__01'), (56, '건강__03'), (56, '가능하'), (55, '형태'), (55, '현상__04'), (55, '재미있'), (55, '잘하'), (55, '연구__03'), (55, '어머니__01'), (55, '비슷하__02'), (55, '대상__11'), (55, '넘__01'), (55, '결국'), (54, '프로그램'), (54, '중독__01'), (54, '원인__02'), (54, '얼마나'), (54, '두__01'), (54, '긍정적'), (53, '활용하'), (53, '즐기__01'), (5 ...

# %%
#단어 붙이기
cell_wordjoin = [' '.join(cutSemanticNum(word) for word in cell) for cell in cell_wordlist]

# %%
#국가별 연관성 분석

# %%
#국가 목록
country_list = ['중국', '미국', '일본', '나우루', '영국', '호주', '스페인', '독일', '인도', '그리스', '러시아', '프랑스', '노르웨이', '콜롬비아', '이탈리아', '브라질', '몽골', '태국', '이란', '몰디브', '모나코', '필리핀', '파라과이', '투발루', '코스타리카', '케냐', '캐나다', '자메이카', '이집트', '예멘', '에티오피아', '스웨덴', '부탄', '베트남', '라오스', '파나마', '탄자니아', '칠레', '인도네시아', '스위스', '스리랑카', '뉴질랜드', '나이지리아', '과테말라']

# %%
선진국 = ['일본','영국','프랑스','독일','그리스','이탈리아','스페인','스웨덴','스위스','노르웨이','콜롬비아','칠레','미국','캐나다','호주','뉴질랜드']
개발도상국 = ['중국','인도','남북','러시아','몽골','태국','필리핀','이란','베트남','몰디브','스리랑카','예멘','부탄','라오스','인도네시아','모나코','이집트','케냐','에티오피아','나이지리아','탄자니아','브라질','파라과이','파나마','코스타리카','자메이카','과테말라','나우루','투발루']

# %%
print(len(선진국)+len(개발도상국))
# Out:
# 45

# %%
아시아 = ['중국','일본','인도','남북','러시아','몽골','태국','필리핀','이란','베트남','몰디브','스리랑카','예멘','부탄','라오스','인도네시아']
유럽 = ['영국','프랑스','독일','그리스','이탈리아','스페인','스웨덴','모나코','스위스','노르웨이'] 
아프리카 = ['이집트','케냐','에티오피아','나이지리아','탄자니아']
남미 = ['브라질','콜롬비아','파라과이','칠레']
북미 = ['미국','캐나다','파나마','코스타리카','자메이카','과테말라'] 
오세아니아 = ['호주','나우루','투발루','뉴질랜드' ]

# %%
print(len(아시아)+len(유럽)+len(아프리카)+len(남미)+len(북미)+len(오세아니아))
# Out:
# 45

# %%
경제수준 = {}
경제수준['선진국'] = 선진국
경제수준['개발도상국'] = 개발도상국

대륙 = {}
대륙['아시아'] = 아시아
대륙['유럽'] = 유럽
대륙['아프리카'] = 아프리카
대륙['남미'] = 남미
대륙['북미'] = 북미
대륙['오세아니아'] = 오세아니아

# %%
#교집합 구하기
def intersect(a, b):
    return list(set(a) & set(b))

# %%
economy = ['선진국','개발도상국']
ground = ['아시아','유럽','아프리카','남미','북미','오세아니아']

# %%
#입력 리스트에 대한 쌍 조합 튜플을 반환
def get_pairs_from_list(lst):
    pairs = []
    unique = list(set(lst)) #리스트 내 중복 제거
    lst_len = len(unique)
    for i in range(lst_len):
        if i==(lst_len-1):
            break
        subset = unique[i+1:]

        for item in subset:
            pairs.append((unique[i], item))
    return pairs

# %%
#group = intersect(대륙['북미'], 경제수준['선진국'])
def get_cell_with_group(group):
    target_cells = []
    for cell in cell_wordjoin:
        for c_name in group:
            if c_name in cell:
                target_cells.append(cell)
                break
    return target_cells

# %%
#name으로 국가그룹단위 연관단어 네트워크 분석
def country_semantic_network(group, name):
    if len(group) < 1:
        return
    #대상 셀 선정
    target_cell_wordjoin = get_cell_with_group(group)
    #단어 합치기
    target_cell_wordlist = [cell.split(" ") for cell in target_cell_wordjoin]    
    word_dic = {}
    for cell in target_cell_wordlist:
        for word in cell:
            word_dic[word] = word_dic.get(word, 0) + 1
    print("총 단어 수 : %d" % len(word_dic))
    word_freq = []
    for key, value in word_dic.items():
        word_freq.append((value, key))
    word_freq.sort(reverse=True)
    #네트워크 생성, gephi를 위한 source-target 생성
    edges = [get_pairs_from_list(cell) for cell in target_cell_wordlist]
    G = nx.Graph()
    for comb in edges:
        for source, dest in comb:
            if G.has_edge(source, dest):
                G[source][dest]['weight'] += 1
            else:
                G.add_edge(source, dest, weight=1)
    print("생성된 그래프 노드 수: %d, 엣지 수 : %d" %(G.number_of_nodes(), G.number_of_edges()))
    ####degree centrality 추출 및 소팅(시간 소요됨)
    start = time.time()
    degree_centrality = nx.degree_centrality(G)
    betweenness_centrality = nx.betweenness_centrality(G)
    print("네트워크 분석 완료 time : %.2f seconds" % (time.time()-start))
    #####degree 추출 및 소팅
    degree = G.degree()
    degree_freq = []
    for key, value in degree:
        degree_freq.append((value, key))
    degree_freq.sort(reverse=True)
    #print("상위 degree", degree_freq[:100])
    
    #결과 데이터 생성
    country_df = pd.DataFrame()
    country_df = pd.DataFrame(columns=['품사','단어','출현빈도','출현빈도/품사빈도','연결단어수','연결중심성','매개중심성','분석범위'])
    for dfreq, word in degree_freq[:200] :
        country_df = country_df.append({'품사':word_tag_dic[word],'단어':word,'출현빈도':word_dic[word],'연결단어수':dfreq,'연결중심성':degree_centrality[word],'매개중심성':betweenness_centrality[word],'분석범위':name,'출현빈도/품사빈도':word_freq_dic[word]/tag_freq_dic[word_tag_dic[word]]}, ignore_index=True)

    DATA_PATH = os.getcwd() + r'\save_data'
    filename = DATA_PATH+'\지문단위_'+name+'.xlsx'
    country_df.to_excel(filename)
    print("%s 저장 완료!" %filename)

# %%
#경제수준별 연관단어 출력 -> 2개 파일 생성
for key in economy:
    country_semantic_network(경제수준[key], key)
    #print(경제수준[key], key)
# Out:
# 총 단어 수 : 4821
# 생성된 그래프 노드 수: 4821, 엣지 수 : 951574
# 네트워크 분석 완료 time : 1408.22 seconds
# C:\Users\Kislee\PycharmProjects\Korean_textbook\save_data\지문단위_선진국.xlsx 저장 완료!
# 총 단어 수 : 4275
# 생성된 그래프 노드 수: 4275, 엣지 수 : 892410
# 네트워크 분석 완료 time : 1157.33 seconds
# C:\Users\Kislee\PycharmProjects\Korean_textbook\save_data\지문단위_개발도상국.xlsx 저장 완료!

# %%
#대륙별 연관단어 출력 -> 6개 파일 생성
for key in ground:
    country_semantic_network(대륙[key], key)
    #print(대륙[key], key)
# Out:
# 총 단어 수 : 4174
# 생성된 그래프 노드 수: 4174, 엣지 수 : 827324
# 네트워크 분석 완료 time : 1004.18 seconds
# C:\Users\Kislee\PycharmProjects\Korean_textbook\save_data\지문단위_아시아.xlsx 저장 완료!
# 총 단어 수 : 3103
# 생성된 그래프 노드 수: 3103, 엣지 수 : 586611
# 네트워크 분석 완료 time : 522.59 seconds
# C:\Users\Kislee\PycharmProjects\Korean_textbook\save_data\지문단위_유럽.xlsx 저장 완료!
# 총 단어 수 : 800
# 생성된 그래프 노드 수: 800, 엣지 수 : 99888
# 네트워크 분석 완료 time : 17.68 seconds
# C:\Users\Kislee\PycharmProjects\Korean_textbook\save_data\지문단위_아프리카.xlsx 저장 완료!
# 총 단어 수 : 647
# 생성된 그래프 노드 수: 647, 엣지 수 : 65845
# 네트워크 분석 완료 time : 9.52 seconds
# C:\Users\Kislee\PycharmProjects\Korean_textbook\save_data\지문단위_남미.xlsx 저장 완료!
# 총 단어 수 : 2900
# 생성된 그래프 노드 수: 2900, 엣지 수 : 483265
# 네트워크 분석 완료 time : 392.13 seconds
# C:\Users\Kislee\PycharmProjects\Korean_textbook\save_data\지문단위_북미.xlsx 저장 완료!
# 총 단어 수 : 1137
# 생성된 그래프 노드 수: 1137, 엣지 수 : 197989
# 네트워크 분석 완료 time : 52.10 seconds
# C:\Users\Kislee\PycharmProjects\Korean_textbook\save_data\지문단위_오세아니아.xlsx 저장 완료!

# %%
#경제수준 및 대륙별 연관단어 출력 -> 12개 파일 생성(선진국아프리카는 없음, 11개 파일)
for eco in economy:
    for gro in ground:
        group = intersect(경제수준[eco], 대륙[gro])
        country_semantic_network(group, eco+'_'+gro)    
        #print(group, eco+gro)
# Out:
# 총 단어 수 : 1924
# 생성된 그래프 노드 수: 1924, 엣지 수 : 283001
# 네트워크 분석 완료 time : 139.97 seconds
# C:\Users\Kislee\PycharmProjects\Korean_textbook\save_data\지문단위_선진국_아시아.xlsx 저장 완료!
# 총 단어 수 : 3103
# 생성된 그래프 노드 수: 3103, 엣지 수 : 586611
# 네트워크 분석 완료 time : 515.30 seconds
# C:\Users\Kislee\PycharmProjects\Korean_textbook\save_data\지문단위_선진국_유럽.xlsx 저장 완료!
# 총 단어 수 : 232
# 생성된 그래프 노드 수: 232, 엣지 수 : 10746
# 네트워크 분석 완료 time : 0.55 seconds
# C:\Users\Kislee\PycharmProjects\Korean_textbook\save_data\지문단위_선진국_남미.xlsx 저장 완료!
# 총 단어 수 : 2786
# 생성된 그래프 노드 수: 2786, 엣지 수 : 464327
# 네트워크 분석 완료 time : 353.97 seconds
# C:\Users\Kislee\PycharmProjects\Korean_textbook\save_data\지문단위_선진국_북미.xlsx 저장 완료!
# 총 단어 수 : 1060
# 생성된 그래프 노드 수: 1060, 엣지 수 : 190458
# 네트워크 분석 완료 time : 45.78 seconds
# C:\Users\Kislee\PycharmProjects\Korean_textbook\save_data\지문단위_선진국_오세아니아.xlsx 저장 완료!
# 총 단어 수 : 3860
# 생성된 그래프 노드 수: 3860, 엣지 수 : 727644
# 네트워크 분석 완료 time : 801.57 seconds
# C:\Users\Kislee\PycharmProjects\Korean_textbook\save_data\지문단위_개발도상국_아시아.xlsx 저장 완료!
# 총 단어 수 : 427
# 생성된 그래프 노드 수: 427, 엣지 수 : 90951
# 네트워크 분석 완료 time : 6.84 seconds
# C:\Users\Kislee\PycharmProjects\Korean_textbook\save_data\지문단위_개발도상국_유럽.xlsx 저장 완료!
# 총 단어 수 : 800
# 생성된 그래프 노드 수: 800, 엣지 수 : 99888
# 네트워크 분석 완료 time : 18.39 seconds
# C:\Users\Kislee\PycharmProjects\Korean_textbook\save_data\지문단위_개발도상국_아프리카.xlsx 저장 완료!
# 총 단어 수 : 538
# 생성된 그래프 노드 수: 538, 엣지 수 : 59149
# 네트워크 분석 완료 time : 6.79 seconds
# C:\Users\Kislee\PycharmProjects\Korean_textbook\save_data\지문단위_개발도상국_남미.xlsx 저장 완료!
# 총 단어 수 : 339
# 생성된 그래프 노드 수: 339, 엣지 수 : 24058
# 네트워크 분석 완료 time : 1.99 seconds
# C:\Users\Kislee\PycharmProjects\Korean_textbook\save_data\지문단위_개발도상국_북미.xlsx 저장 완료!
# 총 단어 수 : 516
# 생성된 그래프 노드 수: 516, 엣지 수 : 96972
# 네트워크 분석 완료 time : 9.71 seconds
# C:\Users\Kislee\PycharmProjects\Korean_textbook\save_data\지문단위_개발도상국_오세아니아.xlsx 저장 완료!

# %%
#코드 종료
